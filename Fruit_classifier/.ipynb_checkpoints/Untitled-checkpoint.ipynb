# %%
from tensorflow import kerasten
# Out:
# 2024-04-17 23:35:34.824354: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-17 23:35:35.540860: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from tensorflow.keras import layers 
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 
import tensorflow as tf

# %%
d_train="fruits-360/Training"
test='fruits-360/Test'
cv="fruits-360/test_multiple_fruits"

# %%
img_h=100
img_w=100

# %%
df=tf.keras.utils.image_dataset_from_directory(d_train,shuffle=True,image_size=(img_h,img_w),validation_split=False,batch_size=32)
# Out:
# Found 41322 files belonging to 81 classes.
# 2024-04-18 00:14:14.279253: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:282] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2024-04-18 00:14:14.279277: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:134] retrieving CUDA diagnostic information for host: hxh-GF65-Thin-9SEXR
# 2024-04-18 00:14:14.279284: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:141] hostname: hxh-GF65-Thin-9SEXR
# 2024-04-18 00:14:14.279390: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:165] libcuda reported version is: 535.171.4
# 2024-04-18 00:14:14.279411: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:169] kernel reported version is: 535.161.7
# ...

# %%
c_names=df.class_names

# %%
test=tf.keras.utils.image_dataset_from_directory(d_cv,shuffle=True,image_size=(img_h,img_w),validation_split=False,batch_size=32)
# Out:
# Found 13877 files belonging to 81 classes.

# %%
df.take(2)
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 100, 100, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
plt.figure(figsize=(10, 10))
for img, label in df.take(1):
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(img[i].numpy().astype("uint8"))
        plt.title(label[i].numpy())  # Assuming label is a tensor
plt.show()
# Out:
# 2024-04-18 00:51:14.609955: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
from tensorflow.keras.models import Sequential
